# %%
import json

# %%
#test = "all_ensemble.json"
#tandard = 'prediction_json/org_rl2_68.json'
standard = 'prediction_json/org_rl2_68.json'
test = "org_ensemble.json"
#standard = 'prediction_json/org_koelectra3_58.json'
with open(standard, 'r') as file:
    standard_data = json.load(file)
with open(test, 'r') as file:
    test_data = json.load(file)

# %%
variance=0
for id in standard_data.keys():
    if standard_data[id] != test_data[id]:
        variance+=1
print(variance)
# Out:
# 82

# %%
files = [
 standard,
 test
] # 불러올 파일들 경로

 
json_files = []
for file in files:
    with open(f"{file}") as f:
        json_file = json.load(f)
        json_files.append(json_file)

# %%
from collections import defaultdict
result = dict()
    
for key in json_files[0].keys(): 
    polls = defaultdict(int)
    
    for json_file in json_files:
        predict = json_file[key]
        polls[predict] += 1
    
    print(polls)
    

    result[key] = voted
# Out:
# defaultdict(<class 'int'>, {'사락사라': 2})
# defaultdict(<class 'int'>, {'냉전': 2})
# defaultdict(<class 'int'>, {'대통령인 빌헬름 미클라스': 1, '빌헬름 미클라스': 1})
# defaultdict(<class 'int'>, {'뉴질랜드': 2})
# defaultdict(<class 'int'>, {'프랑스': 2})
# defaultdict(<class 'int'>, {'다리': 1, '유두': 1})
# defaultdict(<class 'int'>, {'91년 체제': 2})
# defaultdict(<class 'int'>, {'하코네 산의 화산 폭발': 2})
# defaultdict(<class 'int'>, {'순조 11년(1811)': 2})
# defaultdict(<class 'int'>, {'고전도성 철': 2})
# defaultdict(<class 'int'>, {'점쟁이': 1, '리처드 말킨': 1})
# defaultdict(<class 'int'>, {'스탈린그라드': 2})
# defaultdict(<class 'int'>, {'롭 포드': 2})
# defaultdict(<class 'int'>, {'노스햄프턴 교회': 2})
# defaultdict(<class 'int'>, {'언니': 2})
# defaultdict(<class 'int'>, {'석조 궁륭': 2})
# defaultdict(<class 'int'>, {'국민': 1, '국민회의': 1})
# defaultdict(<class 'int'>, {'‘자유’지에': 2})
# defaultdict(<class 'int'>, {'국방부 보고서': 2})
# defaultdict(<class 'int'>, {'입석대(立石臺)': 2})
# defaultdict(<class 'int'>, {'숙의 정씨': 2})
# ...
